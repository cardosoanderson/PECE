# %%
'''Imagem

↓

11.750 features (pixels)

↓

SVD  ← faz a decomposição matemática (montam combinações lineares das features originais olhando para todas as features ao mesmo tempo)

↓

PCA  ← usa essa decomposição "SVD" para encontrar as componentes principais

↓

100 novas features

↓

Classificador




___
Imagens coletadas

↓

Remover imagens inválidas

↓

Padronizar tamanho

↓

Padronizar canais (RGB, escala de cinza...)

↓

Normalizar pixels

↓

Montar o dataset




↓



labels = np.unique(y_test)
print(
    classification_report(
        y_test,
        y_pred,
        labels=labels,
        target_names=[turma_target_names[i] for i in labels]
    )
)

Treinar o modelo'''
